# %%
# pandas-datareader is a separate package that allows you to connect to Google's stock API and grab 
# securities data and read it in as a DataFrame

# %%
import pandas as pd
import pandas_datareader.data as web
import datetime

# %%
start = datetime.datetime(2015,1,1)
end = datetime.datetime(2017,1,1)

# %%
facebook = web.DataReader('FB', 'iex', start,end)
facebook.head()
# Out:
#              open     high     low   close    volume
# date
# 2015-01-02  78.58  78.9300  77.700  78.450  18177475
# 2015-01-05  77.98  79.2455  76.860  77.190  26452191
# 2015-01-06  77.23  77.5900  75.365  76.150  27399288
# 2015-01-07  76.76  77.3600  75.820  76.150  22045333
# 2015-01-08  76.74  78.2300  76.080  78.175  23960953

# %%
# options table
from pandas_datareader.data import Options
fb_options =Options('FB', 'google')
# Out:
# ---------------------------------------------------------------------------
# ImmediateDeprecationError                 Traceback (most recent call last)
# <ipython-input-9-c1543b68d822> in <module>
#       1 # options table
#       2 from pandas_datareader.data import Options
# ----> 3 fb_options =Options('FB', 'google')
#
# ~/.local/lib/python3.6/site-packages/pandas_datareader/data.py in Options(symbol, data_source, session)
#     468         return YahooOptions(symbol, session=session)
#     469     elif data_source == "google":
# --> 470         raise ImmediateDeprecationError(DEP_ERROR_MSG.format('Google Options'))
#     471         return GoogleOptions(symbol, session=session)
#     472     else:
#
# ImmediateDeprecationError:
# Google Options has been immediately deprecated due to large breaks in the API without the
# introduction of a stable replacement. Pull Requests to re-enable these data
# connectors are welcome.
#
# ...

# %% [markdown]
# # Quandl

# %%
import quandl

# %%
data = quandl.get('EIA/PET_RWTC_D')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data.plot()

# %%
mydata = quandl.get('WIKI/AAPL')

# %%
mydata.head()
# Out:
#              Open   High    Low  Close     Volume  Ex-Dividend  Split Ratio  \
# Date
# 1980-12-12  28.75  28.87  28.75  28.75  2093900.0          0.0          1.0
# 1980-12-15  27.38  27.38  27.25  27.25   785200.0          0.0          1.0
# 1980-12-16  25.37  25.37  25.25  25.25   472000.0          0.0          1.0
# 1980-12-17  25.87  26.00  25.87  25.87   385900.0          0.0          1.0
# 1980-12-18  26.63  26.75  26.63  26.63   327900.0          0.0          1.0
#
#             Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
# Date
# 1980-12-12   0.422706   0.424470  0.422706    0.422706  117258400.0
# 1980-12-15   0.402563   0.402563  0.400652    0.400652   43971200.0
# 1980-12-16   0.373010   0.373010  0.371246    0.371246   26432000.0
# 1980-12-17   0.380362   0.382273  0.380362    0.380362   21610400.0
# 1980-12-18   0.391536   0.393300  0.391536    0.391536   18362400.0

# %%
mydata1 = quandl.get('WIKI/AAPL.1')
mydata1
# Out:
#                Open
# Date
# 1980-12-12   28.750
# 1980-12-15   27.380
# 1980-12-16   25.370
# 1980-12-17   25.870
# 1980-12-18   26.630
# 1980-12-19   28.250
# 1980-12-22   29.630
# 1980-12-23   30.880
# 1980-12-24   32.500
# 1980-12-26   35.500
# 1980-12-29   36.000
# 1980-12-30   35.250
# 1980-12-31   34.250
# 1981-01-02   34.500
# 1981-01-05   33.870
# 1981-01-06   32.370
# 1981-01-07   31.000
# 1981-01-08   30.370
# 1981-01-09   31.880
# 1981-01-12   31.880
# 1981-01-13   30.630
# 1981-01-14   30.630
# 1981-01-15   31.250
# 1981-01-16   31.120
# 1981-01-19   32.870
# 1981-01-20   32.000
# 1981-01-21   32.500
# 1981-01-22   32.870
# 1981-01-23   32.870
# 1981-01-26   32.370
# ...             ...
# 2018-02-13  161.950
# 2018-02-14  163.045
# 2018-02-15  169.790
# 2018-02-16  172.360
# 2018-02-20  172.050
# 2018-02-21  172.830
# 2018-02-22  171.800
# 2018-02-23  173.670
# 2018-02-26  176.350
# 2018-02-27  179.100
# 2018-02-28  179.260
# 2018-03-01  178.540
# 2018-03-02  172.800
# ...
